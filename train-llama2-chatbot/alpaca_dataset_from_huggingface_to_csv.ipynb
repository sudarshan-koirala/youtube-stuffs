# %% [markdown]
# <a href="https://colab.research.google.com/github/sudarshan-koirala/youtube-stuffs/blob/main/train-llama2-chatbot/alpaca_dataset_from_huggingface_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
# https://huggingface.co/datasets/tatsu-lab/alpaca
dataset = load_dataset("tatsu-lab/alpaca")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dataset.shape
# Out:
# {'train': (52002, 4)}

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output', 'text'],
#         num_rows: 52002
#     })
# })

# %%
# Loop over the splits and save each one to CSV
for split_name, split_dataset in dataset.items():
    split_dataset.to_csv(f'{split_name}.csv')
# Out:
# Creating CSV from Arrow format:   0%|          | 0/53 [00:00<?, ?ba/s]

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/train.csv")
display(df)
# Out:
#                                              instruction  ...                                               text
# 0                   Give three tips for staying healthy.  ...  Below is an instruction that describes a task....
# 1                     What are the three primary colors?  ...  Below is an instruction that describes a task....
# 2                     Describe the structure of an atom.  ...  Below is an instruction that describes a task....
# 3                       How can we reduce air pollution?  ...  Below is an instruction that describes a task....
# 4      Describe a time when you had to make a difficu...  ...  Below is an instruction that describes a task....
# ...                                                  ...  ...                                                ...
# 51997  Generate an example of what a resume should li...  ...  Below is an instruction that describes a task....
# ...

# %% [markdown]
# # Advanced RAG with LlamaParse and Reranker
#
# <a href="https://colab.research.google.com/github/run-llama/llama_parse/blob/main/examples/demo_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook shows you how to use LlamaParse with our advanced markdown ingestion and recursive retrieval algorithms to model tables/text within a document hierarchically. This lets you ask questions over both tables and text.
#
# Note for this example, we are using the `llama_index >=0.10.4` version

# %%
# %%capture
# !pip install llama-index
# !pip install llama-index-core
# !pip install llama-index-embeddings-openai
# !pip install llama-index-postprocessor-flag-embedding-reranker
# !pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# !pip install llama-parse
# !pip install llama-index-embeddings-fastembed
# !pip install fastembed
# !pip install llama-index-llms-groq
# !pip install watermark

# %%
# !wget 'https://huggingface.co/silaseic/llamaindex_demo/resolve/main/uber_10q_march_2022.pdf?download=true' -O './uber_10q_march_2022.pdf'
# Out:
# --2024-03-31 10:04:54--  https://huggingface.co/silaseic/llamaindex_demo/resolve/main/uber_10q_march_2022.pdf?download=true
# Resolving huggingface.co (huggingface.co)... 65.8.178.118, 65.8.178.27, 65.8.178.93, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.118|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.huggingface.co/repos/db/82/db822043772ccb03c50d147d5942e00187b2c9684beaf6b475f70ff50e2e4b9f/e03fd66bebeef51aa4708a0e5506309734f4676dde85fb5f17f571c0d3f4d4bc?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27uber_10q_march_2022.pdf%3B+filename%3D%22uber_10q_march_2022.pdf%22%3B&response-content-type=application%2Fpdf&Expires=1712138694&Policy=...&Signature=nQP8xZy4Q%7ERQfcOBwO6ZFiGWCa2jNZVnh7zSmBBMJcrgfc2pTY-VYFD4iHLfpTT9HWCyXO25aV6JhCQLeaeI2BokmUXQIDFgtu1LTepzeGD8It%7EGOTzkdGbhq8ACAr6L7Be2ulxIY8tFAos2J29PUGHwEitx%7EjKvZQ1QAFRWVelYpMvn9SSwqITBtTTPBU--VvBxwV6iz-jsfVkmFO7lqeh9lNX4D735jaAgHaPY6IAIrPoshRlDa8qMG5itnyyogAPqYKxsu2H7qFXA15hx1od1oMTLitImAa7LZz7K%7ESC1HAQNJ558Mkv0v90C3ivK%7E7WJmGMvFhOyweHMADr5xA__&Key-Pair-Id=KCD77M1F0VK2B [following]
# --2024-03-31 10:04:54--  https://cdn-lfs-us-1.huggingface.co/repos/db/82/db822043772ccb03c50d147d5942e00187b2c9684beaf6b475f70ff50e2e4b9f/e03fd66bebeef51aa4708a0e5506309734f4676dde85fb5f17f571c0d3f4d4bc?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27uber_10q_march_2022.pdf%3B+filename%3D%22uber_10q_march_2022.pdf%22%3B&response-content-type=application%2Fpdf&Expires=1712138694&Policy=...&Signature=nQP8xZy4Q%7ERQfcOBwO6ZFiGWCa2jNZVnh7zSmBBMJcrgfc2pTY-VYFD4iHLfpTT9HWCyXO25aV6JhCQLeaeI2BokmUXQIDFgtu1LTepzeGD8It%7EGOTzkdGbhq8ACAr6L7Be2ulxIY8tFAos2J29PUGHwEitx%7EjKvZQ1QAFRWVelYpMvn9SSwqITBtTTPBU--VvBxwV6iz-jsfVkmFO7lqeh9lNX4D735jaAgHaPY6IAIrPoshRlDa8qMG5itnyyogAPqYKxsu2H7qFXA15hx1od1oMTLitImAa7LZz7K%7ESC1HAQNJ558Mkv0v90C3ivK%7E7WJmGMvFhOyweHMADr5xA__&Key-Pair-Id=KCD77M1F0VK2B
# Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 13.249.98.16, 13.249.98.111, 13.249.98.99, ...
# Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|13.249.98.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1260185 (1.2M) [application/pdf]
# Saving to: ‘./uber_10q_march_2022.pdf’
#
# ./uber_10q_march_20 100%[===================>]   1.20M  --.-KB/s    in 0.1s
#
# 2024-03-31 10:04:54 (11.8 MB/s) - ‘./uber_10q_march_2022.pdf’ saved [1260185/1260185]

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# API access to llama-cloud
#LLAMA_CLOUD_API_KEY = "llx-*****"

# Using OpenAI API for embeddings/llms
#GROQ_API_KEY = "gsk_*****"

# %% [markdown]
# ## Using brand new `LlamaParse` PDF reader for PDF Parsing
#
# we also compare two different retrieval/query engine strategies:
# 1. Using raw Markdown text as nodes for building index and apply simple query engine for generating the results;
# 2. Using `MarkdownElementNodeParser` for parsing the `LlamaParse` output Markdown results and building recursive retriever query engine for generation.

# %%
from llama_parse import LlamaParse
from google.colab import userdata
LLAMA_CLOUD_API_KEY = userdata.get('LLAMA_CLOUD_API_KEY')

documents = LlamaParse(api_key=LLAMA_CLOUD_API_KEY, result_type="markdown").load_data('./uber_10q_march_2022.pdf')
# Out:
# Started parsing the file under job_id 18c10157-b74f-4da1-8a3f-fad183a6f23f

# %%
print(documents[0].text[:1000] + '...')
# Out:
# ## UNITED STATES SECURITIES AND EXCHANGE COMMISSION Washington, D.C. 20549
#
# ## FORM 10-Q
#
# (Mark One)
#
# ☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 For the quarterly period ended March 31, 2022 OR ☐ TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 For the transition period from_____ to _____ Commission File Number: 001-38902
#
# UBER TECHNOLOGIES, INC. (Exact name of registrant as specified in its charter) Not Applicable (Former name, former address and former fiscal year, if changed since last report)
#
# Delaware 45-2647441 (State or other jurisdiction of incorporation or organization) (I.R.S. Employer Identification No.)
#
# 1515 3rd Street San Francisco, California 94158 (Address of principal executive offices, including zip code) (415) 612-8582 (Registrant’s telephone number, including area code)
#
# Securities registered pursuant to Section 12(b) of the Act:
#
# |Title of each class|Trading Symbol(s)|Name of eac...

# %%
from llama_index.core import VectorStoreIndex
from llama_index.llms.groq import Groq
from llama_index.embeddings.fastembed import FastEmbedEmbedding
from llama_index.core import Settings
GROQ_API_KEY = userdata.get('GROQ_API_KEY')

# by default llamaindex uses OpenAI models
embed_model = FastEmbedEmbedding(model_name="BAAI/bge-base-en-v1.5")

llm = Groq(model="mixtral-8x7b-32768", api_key= GROQ_API_KEY)

Settings.llm = llm
Settings.embed_model = embed_model
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

node_parser = MarkdownElementNodeParser(llm = Groq(model="mixtral-8x7b-32768", api_key= GROQ_API_KEY), num_workers=8)

# %%
nodes = node_parser.get_nodes_from_documents(documents)
# Out:
# 78it [00:00, 21924.39it/s]
#   0%|          | 0/78 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/llama_index/core/program/utils.py:58: UserWarning: Failed to use `OpenAIPydanticProgram`. Please ensure that is installed by running `pip install llama-index-program-openai`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/llama_index/core/program/utils.py:58: UserWarning: Failed to use `OpenAIPydanticProgram`. Please ensure that is installed by running `pip install llama-index-program-openai`.
#   warnings.warn(
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#   1%|▏         | 1/78 [00:02<03:21,  2.62s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-dcee5b2f043b> in <cell line: 1>()
# ----> 1 nodes = node_parser.get_nodes_from_documents(documents)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/interface.py in get_nodes_from_documents(self, documents, show_progress, **kwargs)
#      74             CBEventType.NODE_PARSING, payload={EventPayload.DOCUMENTS: documents}
#      75         ) as event:
# ---> 76             nodes = self._parse_nodes(documents, show_progress=show_progress, **kwargs)
#      77
#      78             for i, node in enumerate(nodes):
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/base_element.py in _parse_nodes(self, nodes, show_progress, **kwargs)
#     118
#     119         for node in nodes_with_progress:
# --> 120             nodes = self.get_nodes_from_node(node)
#     121             all_nodes.extend(nodes)
#     122
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/markdown_element.py in get_nodes_from_node(self, node)
#      30         table_elements = self.get_table_elements(elements)
#      31         # extract summaries over table elements
# ---> 32         self.extract_table_summaries(table_elements)
#      33         # convert into nodes
#      34         # will return a list of Nodes and Index Nodes
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/base_element.py in extract_table_summaries(self, elements)
#     183             for table_context in table_context_list
#     184         ]
# --> 185         summary_outputs = asyncio.run(
#     186             run_jobs(
#     187                 summary_jobs, show_progress=self.show_progress, workers=self.num_workers
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
# ---> 98             return f.result()
#      99
#     100     def _run_once(self):
#
# /usr/lib/python3.10/asyncio/futures.py in result(self)
#     199         self.__log_traceback = False
#     200         if self._exception is not None:
# --> 201             raise self._exception.with_traceback(self._exception_tb)
#     202         return self._result
#     203
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in run_jobs(jobs, show_progress, workers)
#     111     pool_jobs = [worker(job) for job in jobs]
#     112
# --> 113     return await asyncio_mod.gather(*pool_jobs)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/asyncio.py in gather(cls, loop, timeout, total, *fs, **tqdm_kwargs)
#      77
#      78         ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79         res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                                  total=total, **tqdm_kwargs)]
#      81         return [i for _, i in sorted(res)]
#
# /usr/local/lib/python3.10/dist-packages/tqdm/asyncio.py in <listcomp>(.0)
#      77
#      78         ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79         res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                                  total=total, **tqdm_kwargs)]
#      81         return [i for _, i in sorted(res)]
#
# /usr/lib/python3.10/asyncio/tasks.py in _wait_for_one()
#     569             # Dummy value from _on_timeout().
#     570             raise exceptions.TimeoutError
# --> 571         return f.result()  # May raise f.exception().
#     572
#     573     for f in todo:
#
# /usr/lib/python3.10/asyncio/futures.py in result(self)
#     199         self.__log_traceback = False
#     200         if self._exception is not None:
# --> 201             raise self._exception.with_traceback(self._exception_tb)
#     202         return self._result
#     203
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/asyncio.py in wrap_awaitable(i, f)
#      74         """
#      75         async def wrap_awaitable(i, f):
# ---> 76             return i, await f
#      77
#      78         ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in worker(job)
#     107     async def worker(job: Coroutine) -> Any:
#     108         async with semaphore:
# --> 109             return await job
#     110
#     111     pool_jobs = [worker(job) for job in jobs]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/node_parser/relational/base_element.py in _get_table_output(table_context, summary_query_str)
#     170             query_engine = index.as_query_engine(llm=llm, output_cls=TableOutput)
#     171             try:
# --> 172                 response = await query_engine.aquery(summary_query_str)
#     173                 return cast(PydanticResponse, response).response
#     174             except ValidationError:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in aquery(self, str_or_query_bundle)
#      59             if isinstance(str_or_query_bundle, str):
#      60                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 61             query_result = await self._aquery(str_or_query_bundle)
#      62         dispatcher.event(QueryEndEvent())
#      63         return query_result
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in _aquery(self, query_bundle)
#     204             nodes = await self.aretrieve(query_bundle)
#     205
# --> 206             response = await self._response_synthesizer.asynthesize(
#     207                 query=query_bundle,
#     208                 nodes=nodes,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/base.py in asynthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     275             CBEventType.SYNTHESIZE, payload={EventPayload.QUERY_STR: query.query_str}
#     276         ) as event:
# --> 277             response_str = await self.aget_response(
#     278                 query_str=query.query_str,
#     279                 text_chunks=[
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/compact_and_refine.py in aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      21     ) -> RESPONSE_TEXT_TYPE:
#      22         compact_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 23         return await super().aget_response(
#      24             query_str=query_str,
#      25             text_chunks=compact_texts,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     357                 # if this is the first chunk, and text chunk already
#     358                 # is an answer, then return it
# --> 359                 response = await self._agive_response_single(
#     360                     query_str, text_chunk, **response_kwargs
#     361                 )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in _agive_response_single(self, query_str, text_chunk, **response_kwargs)
#     475             if response is None and not self._streaming:
#     476                 try:
# --> 477                     structured_response = await program.acall(
#     478                         context_str=cur_text_chunk,
#     479                         **response_kwargs,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in acall(self, *args, **kwds)
#      90     async def acall(self, *args: Any, **kwds: Any) -> StructuredRefineResponse:
#      91         if self._output_cls is not None:
# ---> 92             answer = await self._llm.astructured_predict(
#      93                 self._output_cls,
#      94                 self._prompt,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py in astructured_predict(self, output_cls, prompt, **prompt_args)
#     377         )
#     378
# --> 379         return await program.acall(**prompt_args)
#     380
#     381     # -- Prompt Chaining --
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py in acall(self, llm_kwargs, *args, **kwargs)
#     128             raw_output = response.text
#     129
# --> 130         output = self._output_parser.parse(raw_output)
#     131         if not isinstance(output, self._output_cls):
#     132             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py in parse(self, text)
#      59     def parse(self, text: str) -> Any:
#      60         """Parse, validate, and correct errors programmatically."""
# ---> 61         json_str = extract_json_str(text)
#      62         return self._output_cls.parse_raw(json_str)
#      63
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/utils.py in extract_json_str(text)
#     110     match = re.search(r"\{.*\}", text.strip(), re.MULTILINE | re.IGNORECASE | re.DOTALL)
#     111     if not match:
# --> 112         raise ValueError(f"Could not extract json string from output: {text}")
#     113
#     114     return match.group()
#
# ValueError: Could not extract json string from output: {
#   "summary": "The table presents financial information related to net income, net loss, and net loss per share attributable to common stockholders for two time periods, potentially 2021 and 2

# %%
#OPENAI_API_KEY = "sk-****"

# %% [markdown]
# Tried Groq's model but timeout issue, json string extraction problem persists, switched to OpenAI model.

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')


embed_model=OpenAIEmbedding(model="text-embedding-3-small", api_key=OPENAI_API_KEY)
llm = OpenAI(model="gpt-3.5-turbo-0125", api_key=OPENAI_API_KEY)

Settings.embed_model = embed_model
Settings.llm = llm

node_parser = MarkdownElementNodeParser(llm = llm, num_workers=8)

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
llm
# Out:
# OpenAI(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7be50e14bcd0>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x7be54a530430>, completion_to_prompt=<function default_completion_to_prompt at 0x7be54a5e16c0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='gpt-3.5-turbo-0125', temperature=0.1, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.openai.com/v1', api_version='')

# %%
nodes = node_parser.get_nodes_from_documents(documents, progress =True)
# Out:
# 78it [00:00, 15905.28it/s]
#   1%|▏         | 1/78 [00:00<01:03,  1.22it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  19%|█▉        | 15/78 [00:05<00:26,  2.35it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  24%|██▍       | 19/78 [00:06<00:15,  3.90it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  33%|███▎      | 26/78 [00:09<00:14,  3.65it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  44%|████▎     | 34/78 [00:11<00:11,  3.84it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  46%|████▌     | 36/78 [00:12<00:16,  2.52it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  51%|█████▏    | 40/78 [00:13<00:08,  4.43it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  56%|█████▋    | 44/78 [00:14<00:06,  5.59it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  64%|██████▍   | 50/78 [00:17<00:09,  2.86it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  74%|███████▍  | 58/78 [00:20<00:07,  2.62it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  83%|████████▎ | 65/78 [00:21<00:03,  3.40it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# 100%|██████████| 78/78 [00:27<00:00,  2.86it/s]

# %%
base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
recursive_index = VectorStoreIndex(nodes=base_nodes+objects)
raw_index = VectorStoreIndex.from_documents(documents)

# %%
from llama_index.postprocessor.flag_embedding_reranker import FlagEmbeddingReranker

reranker = FlagEmbeddingReranker(
    top_n=5,
    model="BAAI/bge-reranker-large",
)

recursive_query_engine = recursive_index.as_query_engine(
    similarity_top_k=15,
    node_postprocessors=[reranker],
    verbose=True
)

raw_query_engine = raw_index.as_query_engine(similarity_top_k=15, node_postprocessors=[reranker])
# Out:
#  69%|██████▉   | 54/78 [19:21<08:36, 21.51s/it]
#  91%|█████████ | 71/78 [22:56<02:15, 19.38s/it]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]

# %%
print(len(nodes))
# Out:
# 299

# %% [markdown]
# ## Using `new LlamaParse` as pdf data parsing methods and retrieve tables with two different methods
# we compare base query engine vs recursive query engine with tables

# %% [markdown]
# ### Table Query Task: Queries for Table Question Answering

# %%
query = "how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# $41
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_40_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_326_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_330_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_38_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_36_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_34_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_274_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_30d6c920-feda-46c7-89fc-096279999005_116_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# Cash paid for income taxes, net of refunds from Supplemental disclosures of cash flow information is $41.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
query = "what is the change of free cash flow and what is the rate from the financial and operational highlights?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The change in free cash flow from the financial and operational highlights is a decrease from $(682) million in 2021 to $(47) million in 2022. This represents a significant improvement in free cash flow performance from one period to the next.
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_320_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_38_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_44_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_324_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_40_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_280_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_42_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_124_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_240_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The change in free cash flow from the financial and operational highlights is an improvement of $635 million, with the rate being a significant increase compared to the same period in the prior year.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
query = "what is the net loss value attributable to Uber compared to last year?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The net loss value attributable to Uber for the current period is $5.9 billion, which is an increase compared to the net loss of $108 million in the same period last year.
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_22_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_316_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_230_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_26_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_234_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_24_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_196_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The net loss value attributable to Uber Technologies, Inc. for the first quarter of 2022 was $5,930 million, which is significantly higher compared to the net loss of $108 million for the same period in 2021.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
query = "What were cash flows like from investing activities?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# Cash flows from investing activities were as follows:
# - For the three months ended March 31, 2022, net cash used in investing activities was $135 million, primarily driven by $62 million in purchases of property and equipment and $59 million in acquisition of business, net of cash acquired.
# - For the three months ended March 31, 2021, net cash used in investing activities was $250 million, mainly consisting of $803 million in purchases of non-marketable equity securities, $336 million in purchases of marketable securities, and $216 million in purchases of a note receivable, partially offset by proceeds from maturities and sales of marketable securities of $696 million and $500 million in proceeds from the sale of non-marketable equity securities.
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_44_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_38_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_324_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_40_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_320_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_42_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_b656577b-91de-47ca-981e-8b1d63e20c20_270_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# Cash flows from investing activities were as follows:
# - For the three months ended March 31, 2021, net cash used in investing activities was $250 million.
# - For the three months ended March 31, 2022, net cash used in investing activities was $135 million.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Give a try and see if it works better in your documents.
